# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# -------------------------------
# DEFINIR EL MODELO
# -------------------------------
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(21,)),  # ← 21 features reales
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)  # Salida continua para regresión
])

model.compile(
    optimizer='adam',
    loss='mean_squared_error',
    metrics=['mae']
)

# -------------------------------
# ENTRENAMIENTO POR LOTES
# -------------------------------
train_folder = "../data_subsets/train_test"
chunk_count = 56   # Número de bloques de entrenamiento
epochs = 10        # Épocas globales
batch_size = 256   # Tamaño de batch interno

print("🚀 Entrenando el modelo por lotes...")

for epoch in range(epochs):
    print(f"\n🌀 Época {epoch+1}/{epochs}")
    for i in range(chunk_count):
        try:
            X_path = os.path.join(train_folder, f"X_train_{i}.npy")
            y_path = os.path.join(train_folder, f"y_train_{i}.npy")

            X_train = np.load(X_path)
            y_train = np.load(y_path)

            print(f"  ➤ Entrenando con chunk {i}... ({X_train.shape[0]} muestras)", end=' ')
            model.fit(X_train, y_train, epochs=1, batch_size=batch_size, verbose=0)
            print("✔️")

            del X_train, y_train

        except FileNotFoundError:
            print(f"⚠️ Chunk {i} no encontrado, saltando.")
            continue

# -------------------------------
# EVALUACIÓN
# -------------------------------
try:
    X_test = np.load(os.path.join(train_folder, "X_test_0.npy"))
    y_test = np.load(os.path.join(train_folder, "y_test_0.npy"))
    print("\n📊 Evaluando modelo en test set...")
    loss, mae = model.evaluate(X_test, y_test)
    print(f"🔍 Loss: {loss:.4f} | MAE: {mae:.4f}")
except FileNotFoundError:
    print("⚠️ No se pudo evaluar el modelo. ¿Falta X_test_0.npy o y_test_0.npy?")

# -------------------------------
# GUARDAR EL MODELO
# -------------------------------
model_path = "../models/flight_price_predictor.h5"
model.save(model_path)
print(f"✅ Modelo guardado en: {model_path}")
# Out:
# 🚀 Entrenando el modelo por lotes...
#
# 🌀 Época 1/10
#   ➤ Entrenando con chunk 0... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 1... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 2... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 3... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 4... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 5... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 6... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 7... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 8... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 9... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 10... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 11... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 12... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 13... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 14... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 15... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 16... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 17... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 18... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 19... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 20... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 21... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 22... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 23... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 24... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 25... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 26... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 27... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 28... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 29... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 30... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 31... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 32... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 33... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 34... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 35... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 36... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 37... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 38... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 39... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 40... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 41... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 42... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 43... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 44... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 45... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 46... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 47... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 48... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 49... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 50... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 51... (587508 muestras) ✔️
#   ➤ Entrenando con chunk 52... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 53... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 54... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 55... (838860 muestras) ✔️
#
# 🌀 Época 2/10
#   ➤ Entrenando con chunk 0... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 1... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 2... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 3... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 4... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 5... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 6... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 7... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 8... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 9... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 10... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 11... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 12... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 13... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 14... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 15... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 16... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 17... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 18... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 19... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 20... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 21... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 22... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 23... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 24... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 25... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 26... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 27... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 28... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 29... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 30... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 31... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 32... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 33... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 34... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 35... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 36... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 37... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 38... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 39... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 40... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 41... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 42... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 43... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 44... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 45... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 46... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 47... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 48... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 49... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 50... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 51... (587508 muestras) ✔️
#   ➤ Entrenando con chunk 52... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 53... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 54... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 55... (838860 muestras) ✔️
#
# 🌀 Época 3/10
#   ➤ Entrenando con chunk 0... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 1... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 2... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 3... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 4... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 5... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 6... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 7... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 8... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 9... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 10... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 11... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 12... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 13... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 14... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 15... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 16... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 17... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 18... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 19... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 20... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 21... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 22... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 23... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 24... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 25... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 26... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 27... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 28... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 29... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 30... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 31... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 32... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 33... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 34... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 35... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 36... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 37... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 38... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 39... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 40... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 41... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 42... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 43... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 44... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 45... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 46... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 47... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 48... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 49... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 50... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 51... (587508 muestras) ✔️
#   ➤ Entrenando con chunk 52... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 53... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 54... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 55... (838860 muestras) ✔️
#
# 🌀 Época 4/10
#   ➤ Entrenando con chunk 0... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 1... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 2... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 3... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 4... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 5... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 6... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 7... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 8... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 9... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 10... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 11... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 12... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 13... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 14... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 15... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 16... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 17... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 18... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 19... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 20... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 21... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 22... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 23... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 24... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 25... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 26... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 27... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 28... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 29... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 30... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 31... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 32... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 33... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 34... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 35... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 36... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 37... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 38... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 39... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 40... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 41... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 42... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 43... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 44... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 45... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 46... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 47... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 48... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 49... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 50... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 51... (587508 muestras) ✔️
#   ➤ Entrenando con chunk 52... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 53... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 54... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 55... (838860 muestras) ✔️
#
# 🌀 Época 5/10
#   ➤ Entrenando con chunk 0... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 1... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 2... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 3... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 4... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 5... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 6... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 7... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 8... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 9... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 10... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 11... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 12... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 13... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 14... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 15... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 16... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 17... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 18... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 19... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 20... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 21... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 22... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 23... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 24... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 25... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 26... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 27... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 28... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 29... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 30... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 31... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 32... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 33... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 34... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 35... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 36... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 37... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 38... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 39... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 40... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 41... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 42... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 43... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 44... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 45... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 46... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 47... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 48... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 49... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 50... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 51... (587508 muestras) ✔️
#   ➤ Entrenando con chunk 52... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 53... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 54... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 55... (838860 muestras) ✔️
#
# 🌀 Época 6/10
#   ➤ Entrenando con chunk 0... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 1... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 2... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 3... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 4... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 5... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 6... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 7... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 8... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 9... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 10... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 11... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 12... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 13... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 14... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 15... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 16... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 17... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 18... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 19... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 20... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 21... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 22... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 23... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 24... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 25... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 26... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 27... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 28... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 29... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 30... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 31... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 32... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 33... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 34... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 35... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 36... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 37... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 38... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 39... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 40... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 41... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 42... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 43... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 44... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 45... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 46... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 47... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 48... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 49... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 50... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 51... (587508 muestras) ✔️
#   ➤ Entrenando con chunk 52... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 53... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 54... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 55... (838860 muestras) ✔️
#
# 🌀 Época 7/10
#   ➤ Entrenando con chunk 0... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 1... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 2... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 3... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 4... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 5... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 6... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 7... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 8... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 9... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 10... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 11... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 12... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 13... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 14... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 15... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 16... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 17... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 18... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 19... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 20... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 21... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 22... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 23... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 24... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 25... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 26... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 27... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 28... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 29... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 30... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 31... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 32... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 33... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 34... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 35... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 36... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 37... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 38... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 39... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 40... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 41... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 42... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 43... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 44... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 45... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 46... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 47... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 48... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 49... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 50... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 51... (587508 muestras) ✔️
#   ➤ Entrenando con chunk 52... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 53... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 54... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 55... (838860 muestras) ✔️
#
# 🌀 Época 8/10
#   ➤ Entrenando con chunk 0... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 1... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 2... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 3... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 4... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 5... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 6... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 7... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 8... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 9... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 10... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 11... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 12... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 13... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 14... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 15... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 16... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 17... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 18... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 19... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 20... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 21... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 22... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 23... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 24... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 25... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 26... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 27... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 28... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 29... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 30... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 31... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 32... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 33... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 34... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 35... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 36... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 37... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 38... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 39... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 40... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 41... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 42... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 43... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 44... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 45... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 46... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 47... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 48... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 49... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 50... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 51... (587508 muestras) ✔️
#   ➤ Entrenando con chunk 52... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 53... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 54... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 55... (838860 muestras) ✔️
#
# 🌀 Época 9/10
#   ➤ Entrenando con chunk 0... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 1... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 2... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 3... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 4... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 5... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 6... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 7... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 8... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 9... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 10... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 11... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 12... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 13... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 14... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 15... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 16... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 17... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 18... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 19... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 20... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 21... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 22... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 23... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 24... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 25... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 26... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 27... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 28... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 29... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 30... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 31... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 32... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 33... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 34... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 35... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 36... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 37... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 38... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 39... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 40... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 41... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 42... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 43... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 44... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 45... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 46... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 47... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 48... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 49... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 50... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 51... (587508 muestras) ✔️
#   ➤ Entrenando con chunk 52... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 53... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 54... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 55... (838860 muestras) ✔️
#
# 🌀 Época 10/10
#   ➤ Entrenando con chunk 0... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 1... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 2... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 3... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 4... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 5... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 6... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 7... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 8... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 9... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 10... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 11... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 12... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 13... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 14... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 15... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 16... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 17... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 18... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 19... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 20... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 21... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 22... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 23... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 24... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 25... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 26... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 27... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 28... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 29... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 30... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 31... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 32... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 33... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 34... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 35... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 36... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 37... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 38... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 39... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 40... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 41... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 42... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 43... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 44... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 45... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 46... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 47... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 48... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 49... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 50... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 51... (587508 muestras) ✔️
#   ➤ Entrenando con chunk 52... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 53... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 54... (838860 muestras) ✔️
#   ➤ Entrenando con chunk 55... (838860 muestras) ✔️
#
# 📊 Evaluando modelo en test set...
# 6554/6554 ━━━━━━━━━━━━━━━━━━━━ 4s 630us/step - loss: nan - mae: nan
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 🔍 Loss: nan | MAE: nan
# ✅ Modelo guardado en: ../models/flight_price_predictor.h5

# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# -------------------------------
# DEFINICIÓN DEL MODELO
# -------------------------------
optimizer = keras.optimizers.Adam(learning_rate=0.0005)

model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(21,)),  # Ajustado a tu número de features
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])

model.compile(
    optimizer=optimizer,
    loss='mean_squared_error',
    metrics=['mae']
)

# -------------------------------
# ENTRENAMIENTO POR LOTES
# -------------------------------
train_folder = "../data_subsets/train_test"
chunk_count = 56   # Ajusta al número real de bloques
epochs = 10        # Número de épocas completas
batch_size = 256   # Tamaño de mini-batch

print("🚀 Entrenando el modelo por lotes...")

for epoch in range(epochs):
    print(f"\n🌀 Época {epoch+1}/{epochs}")
    for i in range(chunk_count):
        try:
            X_path = os.path.join(train_folder, f"X_train_{i}.npy")
            y_path = os.path.join(train_folder, f"y_train_{i}.npy")

            X_train = np.load(X_path)
            y_train = np.load(y_path)

            # COMPROBACIÓN DE NaNs
            if np.isnan(X_train).any() or np.isnan(y_train).any():
                print(f"❌ Chunk {i} tiene NaNs, lo saltamos.")
                continue

            # ESCALADO DE y_train
            y_train = y_train / 1000.0

            print(f"  ➤ Entrenando con chunk {i}... ({X_train.shape[0]} muestras)", end=' ')
            model.fit(X_train, y_train, epochs=1, batch_size=batch_size, verbose=0)
            print("✔️")

            del X_train, y_train

        except FileNotFoundError:
            print(f"⚠️ Chunk {i} no encontrado, saltando.")
            continue

# -------------------------------
# EVALUACIÓN
# -------------------------------
try:
    X_test = np.load(os.path.join(train_folder, "X_test_0.npy"))
    y_test = np.load(os.path.join(train_folder, "y_test_0.npy"))

    if np.isnan(X_test).any() or np.isnan(y_test).any():
        raise ValueError("❌ El set de test contiene NaNs.")

    y_test = y_test / 1000.0  # Escalar test igual que train

    print("\n📊 Evaluando modelo en test set...")
    loss, mae = model.evaluate(X_test, y_test)
    print(f"🔍 Loss: {loss:.4f} | MAE: {mae:.4f}")

except Exception as e:
    print(f"⚠️ No se pudo evaluar el modelo: {e}")

# -------------------------------
# GUARDAR MODELO ENTRENADO
# -------------------------------
model_path = "../models/flight_price_predictor_v2_scaled_lr005.h5"
model.save(model_path)
print(f"✅ Modelo guardado en: {model_path}")
# Out:
# 🚀 Entrenando el modelo por lotes...
#
# 🌀 Época 1/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 2/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 3/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 4/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 5/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 6/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 7/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 8/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 9/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 10/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 📊 Evaluando modelo en test set...
# 5954/5954 ━━━━━━━━━━━━━━━━━━━━ 4s 622us/step - loss: 3.2117e-06 - mae: 0.0012
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 🔍 Loss: 0.0000 | MAE: 0.0012
# ✅ Modelo guardado en: ../models/flight_price_predictor_v2_scaled_lr005.h5

# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# -------------------------------
# DEFINICIÓN DEL MODELO
# -------------------------------
optimizer = keras.optimizers.Adam(learning_rate=0.0005)

model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(21,)),  # Ajustado a tu número de features
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])

model.compile(
    optimizer=optimizer,
    loss='mean_squared_error',
    metrics=['mae']
)

# -------------------------------
# ENTRENAMIENTO POR LOTES
# -------------------------------
train_folder = "../data_subsets/train_test"
chunk_count = 56   # Ajusta al número real de bloques
epochs = 10        # Número de épocas completas
batch_size = 256   # Tamaño de mini-batch

print("🚀 Entrenando el modelo por lotes...")

for epoch in range(epochs):
    print(f"\n🌀 Época {epoch+1}/{epochs}")
    for i in range(chunk_count):
        try:
            X_path = os.path.join(train_folder, f"X_train_{i}.npy")
            y_path = os.path.join(train_folder, f"y_train_{i}.npy")

            X_train = np.load(X_path)
            y_train = np.load(y_path)

            # COMPROBACIÓN DE NaNs
            if np.isnan(X_train).any() or np.isnan(y_train).any():
                print(f"❌ Chunk {i} tiene NaNs, lo saltamos.")
                continue

            # ESCALADO DE y_train
            y_train = y_train / 1000.0

            print(f"  ➤ Entrenando con chunk {i}... ({X_train.shape[0]} muestras)", end=' ')
            model.fit(X_train, y_train, epochs=1, batch_size=batch_size, verbose=0)
            print("✔️")

            del X_train, y_train

        except FileNotFoundError:
            print(f"⚠️ Chunk {i} no encontrado, saltando.")
            continue

# -------------------------------
# EVALUACIÓN RÁPIDA (chunk 0)
# -------------------------------
try:
    X_test = np.load(os.path.join(train_folder, "X_test_0.npy"))
    y_test = np.load(os.path.join(train_folder, "y_test_0.npy"))

    if np.isnan(X_test).any() or np.isnan(y_test).any():
        raise ValueError("❌ El set de test contiene NaNs.")

    y_test = y_test / 1000.0  # Escalar test igual que train

    print("\n📊 Evaluando modelo en test set (chunk 0)...")
    loss, mae = model.evaluate(X_test, y_test)
    print(f"🔍 Loss: {loss:.4f} | MAE: {mae:.4f}")

except Exception as e:
    print(f"⚠️ No se pudo evaluar el modelo: {e}")

# -------------------------------
# GUARDAR MODELO ENTRENADO
# -------------------------------
model_path = "../models/flight_price_predictor_global_eval.h5"
model.save(model_path)
print(f"✅ Modelo guardado en: {model_path}")

# -------------------------------
# EVALUACIÓN GLOBAL SOBRE TODOS LOS CHUNKS DE TEST
# -------------------------------
print("\n📊 Evaluando modelo con TODOS los chunks de test...")

total_loss = 0
total_mae = 0
total_samples = 0

for i in range(chunk_count):
    try:
        X_test = np.load(f"{train_folder}/X_test_{i}.npy")
        y_test = np.load(f"{train_folder}/y_test_{i}.npy")
        
        y_test = y_test / 1000.0  # desescalar
        loss, mae = model.evaluate(X_test, y_test, verbose=0)
        
        total_loss += loss * len(y_test)
        total_mae += mae * len(y_test)
        total_samples += len(y_test)

        print(f"✅ Chunk {i:02d}: MAE = {mae:.4f}, Samples = {len(y_test)}")

    except FileNotFoundError:
        print(f"⚠️ Chunk {i:02d} no encontrado, se omite.")
        continue

if total_samples > 0:
    avg_loss = total_loss / total_samples
    avg_mae = total_mae / total_samples
    print("\n📈 MÉTRICAS GLOBALES SOBRE TODO EL TEST SET")
    print(f"🔹 Loss promedio: {avg_loss:.6f}")
    print(f"🔹 MAE promedio:  {avg_mae:.4f} (×1000 = {avg_mae * 1000:.2f} €)")
else:
    print("❌ No se encontraron datos de test para evaluar.")
# Out:
# 🚀 Entrenando el modelo por lotes...
#
# 🌀 Época 1/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 2/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 3/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 4/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 5/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 6/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 7/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 8/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 9/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 🌀 Época 10/10
#   ➤ Entrenando con chunk 0... (762107 muestras) ✔️
#   ➤ Entrenando con chunk 1... (759244 muestras) ✔️
#   ➤ Entrenando con chunk 2... (735888 muestras) ✔️
#   ➤ Entrenando con chunk 3... (735300 muestras) ✔️
#   ➤ Entrenando con chunk 4... (735871 muestras) ✔️
#   ➤ Entrenando con chunk 5... (737430 muestras) ✔️
#   ➤ Entrenando con chunk 6... (736117 muestras) ✔️
#   ➤ Entrenando con chunk 7... (736203 muestras) ✔️
#   ➤ Entrenando con chunk 8... (734632 muestras) ✔️
#   ➤ Entrenando con chunk 9... (737012 muestras) ✔️
#   ➤ Entrenando con chunk 10... (738777 muestras) ✔️
#   ➤ Entrenando con chunk 11... (740420 muestras) ✔️
#   ➤ Entrenando con chunk 12... (755498 muestras) ✔️
#   ➤ Entrenando con chunk 13... (734076 muestras) ✔️
#   ➤ Entrenando con chunk 14... (615153 muestras) ✔️
#   ➤ Entrenando con chunk 15... (714638 muestras) ✔️
#   ➤ Entrenando con chunk 16... (746610 muestras) ✔️
#   ➤ Entrenando con chunk 17... (745083 muestras) ✔️
#   ➤ Entrenando con chunk 18... (745923 muestras) ✔️
#   ➤ Entrenando con chunk 19... (745884 muestras) ✔️
#   ➤ Entrenando con chunk 20... (750080 muestras) ✔️
#   ➤ Entrenando con chunk 21... (749208 muestras) ✔️
#   ➤ Entrenando con chunk 22... (750684 muestras) ✔️
#   ➤ Entrenando con chunk 23... (755247 muestras) ✔️
#   ➤ Entrenando con chunk 24... (757395 muestras) ✔️
#   ➤ Entrenando con chunk 25... (755549 muestras) ✔️
#   ➤ Entrenando con chunk 26... (751506 muestras) ✔️
#   ➤ Entrenando con chunk 27... (755648 muestras) ✔️
#   ➤ Entrenando con chunk 28... (753525 muestras) ✔️
#   ➤ Entrenando con chunk 29... (756676 muestras) ✔️
#   ➤ Entrenando con chunk 30... (758286 muestras) ✔️
#   ➤ Entrenando con chunk 31... (757452 muestras) ✔️
#   ➤ Entrenando con chunk 32... (761024 muestras) ✔️
#   ➤ Entrenando con chunk 33... (761400 muestras) ✔️
#   ➤ Entrenando con chunk 34... (745132 muestras) ✔️
#   ➤ Entrenando con chunk 35... (760998 muestras) ✔️
#   ➤ Entrenando con chunk 36... (764969 muestras) ✔️
#   ➤ Entrenando con chunk 37... (762431 muestras) ✔️
#   ➤ Entrenando con chunk 38... (765272 muestras) ✔️
#   ➤ Entrenando con chunk 39... (763861 muestras) ✔️
#   ➤ Entrenando con chunk 40... (762356 muestras) ✔️
#   ➤ Entrenando con chunk 41... (762964 muestras) ✔️
#   ➤ Entrenando con chunk 42... (760291 muestras) ✔️
#   ➤ Entrenando con chunk 43... (761947 muestras) ✔️
#   ➤ Entrenando con chunk 44... (761731 muestras) ✔️
#   ➤ Entrenando con chunk 45... (739752 muestras) ✔️
#   ➤ Entrenando con chunk 46... (762272 muestras) ✔️
#   ➤ Entrenando con chunk 47... (760731 muestras) ✔️
#   ➤ Entrenando con chunk 48... (762737 muestras) ✔️
#   ➤ Entrenando con chunk 49... (747460 muestras) ✔️
#   ➤ Entrenando con chunk 50... (758256 muestras) ✔️
#   ➤ Entrenando con chunk 51... (533324 muestras) ✔️
#   ➤ Entrenando con chunk 52... (723708 muestras) ✔️
#   ➤ Entrenando con chunk 53... (702082 muestras) ✔️
#   ➤ Entrenando con chunk 54... (722292 muestras) ✔️
#   ➤ Entrenando con chunk 55... (738651 muestras) ✔️
#
# 📊 Evaluando modelo en test set (chunk 0)...
# 5954/5954 ━━━━━━━━━━━━━━━━━━━━ 4s 640us/step - loss: 3.1946e-06 - mae: 0.0011
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 🔍 Loss: 0.0000 | MAE: 0.0011
# ✅ Modelo guardado en: ../models/flight_price_predictor_global_eval.h5
#
# 📊 Evaluando modelo con TODOS los chunks de test...
# ✅ Chunk 00: MAE = 0.0011, Samples = 190527
# ✅ Chunk 01: MAE = 0.0011, Samples = 189811
# ✅ Chunk 02: MAE = 0.0010, Samples = 183972
# ✅ Chunk 03: MAE = 0.0010, Samples = 183825
# ✅ Chunk 04: MAE = 0.0010, Samples = 183968
# ✅ Chunk 05: MAE = 0.0010, Samples = 184358
# ✅ Chunk 06: MAE = 0.0010, Samples = 184030
# ✅ Chunk 07: MAE = 0.0010, Samples = 184051
# ✅ Chunk 08: MAE = 0.0010, Samples = 183659
# ✅ Chunk 09: MAE = 0.0010, Samples = 184253
# ✅ Chunk 10: MAE = 0.0010, Samples = 184695
# ✅ Chunk 11: MAE = 0.0010, Samples = 185106
# ✅ Chunk 12: MAE = 0.0010, Samples = 188875
# ✅ Chunk 13: MAE = 0.0010, Samples = 183519
# ✅ Chunk 14: MAE = 0.0010, Samples = 153789
# ✅ Chunk 15: MAE = 0.0010, Samples = 178660
# ✅ Chunk 16: MAE = 0.0010, Samples = 186653
# ✅ Chunk 17: MAE = 0.0010, Samples = 186271
# ✅ Chunk 18: MAE = 0.0010, Samples = 186481
# ✅ Chunk 19: MAE = 0.0010, Samples = 186472
# ✅ Chunk 20: MAE = 0.0010, Samples = 187520
# ✅ Chunk 21: MAE = 0.0010, Samples = 187302
# ✅ Chunk 22: MAE = 0.0010, Samples = 187671
# ✅ Chunk 23: MAE = 0.0010, Samples = 188812
# ✅ Chunk 24: MAE = 0.0010, Samples = 189349
# ✅ Chunk 25: MAE = 0.0010, Samples = 188888
# ✅ Chunk 26: MAE = 0.0010, Samples = 187877
# ✅ Chunk 27: MAE = 0.0010, Samples = 188912
# ✅ Chunk 28: MAE = 0.0010, Samples = 188382
# ✅ Chunk 29: MAE = 0.0010, Samples = 189169
# ✅ Chunk 30: MAE = 0.0010, Samples = 189572
# ✅ Chunk 31: MAE = 0.0010, Samples = 189363
# ✅ Chunk 32: MAE = 0.0011, Samples = 190257
# ✅ Chunk 33: MAE = 0.0011, Samples = 190351
# ✅ Chunk 34: MAE = 0.0010, Samples = 186283
# ✅ Chunk 35: MAE = 0.0011, Samples = 190250
# ✅ Chunk 36: MAE = 0.0011, Samples = 191243
# ✅ Chunk 37: MAE = 0.0011, Samples = 190608
# ✅ Chunk 38: MAE = 0.0011, Samples = 191318
# ✅ Chunk 39: MAE = 0.0011, Samples = 190966
# ✅ Chunk 40: MAE = 0.0011, Samples = 190590
# ✅ Chunk 41: MAE = 0.0012, Samples = 190741
# ✅ Chunk 42: MAE = 0.0012, Samples = 190073
# ✅ Chunk 43: MAE = 0.0012, Samples = 190487
# ✅ Chunk 44: MAE = 0.0012, Samples = 190433
# ✅ Chunk 45: MAE = 0.0010, Samples = 184938
# ✅ Chunk 46: MAE = 0.0012, Samples = 190569
# ✅ Chunk 47: MAE = 0.0012, Samples = 190183
# ✅ Chunk 48: MAE = 0.0012, Samples = 190685
# ✅ Chunk 49: MAE = 0.0012, Samples = 186865
# ✅ Chunk 50: MAE = 0.0012, Samples = 189564
# ✅ Chunk 51: MAE = 0.0013, Samples = 133332
# ✅ Chunk 52: MAE = 0.0010, Samples = 180928
# ✅ Chunk 53: MAE = 0.0010, Samples = 175521
# ✅ Chunk 54: MAE = 0.0010, Samples = 180574
# ✅ Chunk 55: MAE = 0.0010, Samples = 184663
#
# 📈 MÉTRICAS GLOBALES SOBRE TODO EL TEST SET
# 🔹 Loss promedio: 0.000003
# 🔹 MAE promedio:  0.0011 (×1000 = 1.05 €)

# %%
import numpy as np
import pandas as pd
import os
import glob
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
import joblib
import matplotlib.pyplot as plt


# -------------------------------
# 1. CARGAR Y FILTRAR LOS DATOS
# -------------------------------
chunks_path = "../data_subsets/final_dataset_chunks/final_chunk_*.parquet"
all_chunks = [pd.read_parquet(file) for file in sorted(glob.glob(chunks_path))]
df = pd.concat(all_chunks, ignore_index=True)

# Eliminar columnas no necesarias (como legId)
df = df.drop(columns=['legId'])

# Filtrar outliers en el precio
q1 = df['totalFare'].quantile(0.01)
q99 = df['totalFare'].quantile(0.99)
df = df[(df['totalFare'] >= q1) & (df['totalFare'] <= q99)]

# -------------------------------
# 2. SEPARAR VARIABLES Y ESCALAR
# -------------------------------
X = df.drop(columns=['totalFare'])
y = df['totalFare'] / 1000.0  # escalar objetivo

scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Guardar el scaler
joblib.dump(scaler, "../models/robust_scaler.pkl")

# -------------------------------
# 3. DEFINICIÓN DEL MODELO CON REGULARIZACIÓN
# -------------------------------
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],),
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.2),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),
    loss='mean_squared_error',
    metrics=['mae']
)

# -------------------------------
# 4. ENTRENAMIENTO CON VALIDACIÓN
# -------------------------------
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=20,
    batch_size=256,
    verbose=1
)

# -------------------------------
# 5. EVALUACIÓN Y GUARDADO
# -------------------------------
loss, mae = model.evaluate(X_test, y_test)
print(f"\n✅ Evaluación final - Loss: {loss:.6f} | MAE: {mae:.4f} (×1000 = {mae * 1000:.2f} €)")

model.save("../models/flight_price_predictor_v3_regularized.h5")

# -------------------------------
# 6. GRÁFICA DE ENTRENAMIENTO
# -------------------------------
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title("Pérdida durante el entrenamiento")
plt.xlabel("Épocas")
plt.ylabel("Loss")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 19
#      17 chunks_path = "../data_subsets/final_dataset_chunks/final_chunk_*.parquet"
#      18 all_chunks = [pd.read_parquet(file) for file in sorted(glob.glob(chunks_path))]
# ---> 19 df = pd.concat(all_chunks, ignore_index=True)
#      21 # Eliminar columnas no necesarias (como legId)
#      22 df = df.drop(columns=['legId'])
#
# File ~/flightprice_env/lib/python3.12/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/flightprice_env/lib/python3.12/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/flightprice_env/lib/python3.12/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import joblib

# -------------------------------
# DEFINICIÓN DEL MODELO
# -------------------------------
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(21,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),
    loss='mean_squared_error',
    metrics=['mae']
)

# -------------------------------
# ENTRENAMIENTO POR LOTES
# -------------------------------
train_folder = "../data_subsets/train_test"
chunk_count = 56   # Ajusta si tienes más o menos
epochs = 10        # Número de épocas completas
batch_size = 256

print("🚀 Entrenando el modelo por lotes...")
for epoch in range(epochs):
    print(f"\n🌀 Época {epoch+1}/{epochs}")
    for i in range(chunk_count):
        try:
            X_path = os.path.join(train_folder, f"X_train_{i}.npy")
            y_path = os.path.join(train_folder, f"y_train_{i}.npy")

            X_train = np.load(X_path)
            y_train = np.load(y_path)

            if np.isnan(X_train).any() or np.isnan(y_train).any():
                print(f"❌ Chunk {i} tiene NaNs, lo saltamos.")
                continue

            y_train = y_train / 1000.0  # Escalar si es necesario

            print(f"  ➤ Entrenando con chunk {i}... ({X_train.shape[0]} muestras)", end=' ')
            model.fit(X_train, y_train, epochs=1, batch_size=batch_size, verbose=0)
            print("✔️")

            del X_train, y_train

        except FileNotFoundError:
            print(f"⚠️ Chunk {i} no encontrado, saltando.")
            continue

# -------------------------------
# EVALUACIÓN GLOBAL SOBRE TODOS LOS TEST
# -------------------------------
print("\n📊 Evaluando el modelo sobre todos los test chunks...")
maes = []
losses = []
samples_total = 0

for i in range(chunk_count):
    try:
        X_test = np.load(os.path.join(train_folder, f"X_test_{i}.npy"))
        y_test = np.load(os.path.join(train_folder, f"y_test_{i}.npy"))

        if np.isnan(X_test).any() or np.isnan(y_test).any():
            print(f"❌ Chunk {i} tiene NaNs, lo saltamos.")
            continue

        y_test = y_test / 1000.0  # Escalar si fue escalado igual que train
        loss, mae = model.evaluate(X_test, y_test, verbose=0)

        maes.append(mae * X_test.shape[0])
        losses.append(loss * X_test.shape[0])
        samples_total += X_test.shape[0]

        print(f"✅ Chunk {i}: MAE = {mae:.4f}, Samples = {X_test.shape[0]}")

    except FileNotFoundError:
        continue

# -------------------------------
# RESULTADO GLOBAL PROMEDIO
# -------------------------------
if samples_total > 0:
    avg_mae = sum(maes) / samples_total
    avg_loss = sum(losses) / samples_total
    print("\n📌 MÉTRICAS GLOBALES SOBRE TODO EL TEST SET")
    print(f"🔷 Loss promedio: {avg_loss:.6f}")
    print(f"🔷 MAE promedio: {avg_mae:.4f} (×1000 = {avg_mae * 1000:.2f} €)")
else:
    print("⚠️ No se pudo evaluar el modelo: ningún chunk válido.")

# -------------------------------
# GUARDAR MODELO
# -------------------------------
model_path = "../models/flight_price_predictor_v3_clean_scaled.h5"
model.save(model_path)
print(f"\n💾 Modelo guardado en: {model_path}")
# Out:
# 🚀 Entrenando el modelo por lotes...
#
# 🌀 Época 1/10
# ❌ Chunk 0 tiene NaNs, lo saltamos.
# ❌ Chunk 1 tiene NaNs, lo saltamos.
# ❌ Chunk 2 tiene NaNs, lo saltamos.
# ❌ Chunk 3 tiene NaNs, lo saltamos.
# ❌ Chunk 4 tiene NaNs, lo saltamos.
# ❌ Chunk 5 tiene NaNs, lo saltamos.
# ❌ Chunk 6 tiene NaNs, lo saltamos.
# ❌ Chunk 7 tiene NaNs, lo saltamos.
# ❌ Chunk 8 tiene NaNs, lo saltamos.
# ❌ Chunk 9 tiene NaNs, lo saltamos.
# ❌ Chunk 10 tiene NaNs, lo saltamos.
# ❌ Chunk 11 tiene NaNs, lo saltamos.
# ❌ Chunk 12 tiene NaNs, lo saltamos.
# ❌ Chunk 13 tiene NaNs, lo saltamos.
# ❌ Chunk 14 tiene NaNs, lo saltamos.
# ❌ Chunk 15 tiene NaNs, lo saltamos.
# ❌ Chunk 16 tiene NaNs, lo saltamos.
# ❌ Chunk 17 tiene NaNs, lo saltamos.
# ❌ Chunk 18 tiene NaNs, lo saltamos.
# ❌ Chunk 19 tiene NaNs, lo saltamos.
# ❌ Chunk 20 tiene NaNs, lo saltamos.
# ❌ Chunk 21 tiene NaNs, lo saltamos.
# ❌ Chunk 22 tiene NaNs, lo saltamos.
# ❌ Chunk 23 tiene NaNs, lo saltamos.
# ❌ Chunk 24 tiene NaNs, lo saltamos.
# ❌ Chunk 25 tiene NaNs, lo saltamos.
# ❌ Chunk 26 tiene NaNs, lo saltamos.
# ❌ Chunk 27 tiene NaNs, lo saltamos.
# ❌ Chunk 28 tiene NaNs, lo saltamos.
# ❌ Chunk 29 tiene NaNs, lo saltamos.
# ❌ Chunk 30 tiene NaNs, lo saltamos.
# ❌ Chunk 31 tiene NaNs, lo saltamos.
# ❌ Chunk 32 tiene NaNs, lo saltamos.
# ❌ Chunk 33 tiene NaNs, lo saltamos.
# ❌ Chunk 34 tiene NaNs, lo saltamos.
# ❌ Chunk 35 tiene NaNs, lo saltamos.
# ❌ Chunk 36 tiene NaNs, lo saltamos.
# ❌ Chunk 37 tiene NaNs, lo saltamos.
# ❌ Chunk 38 tiene NaNs, lo saltamos.
# ❌ Chunk 39 tiene NaNs, lo saltamos.
# ❌ Chunk 40 tiene NaNs, lo saltamos.
# ❌ Chunk 41 tiene NaNs, lo saltamos.
# ❌ Chunk 42 tiene NaNs, lo saltamos.
# ❌ Chunk 43 tiene NaNs, lo saltamos.
# ❌ Chunk 44 tiene NaNs, lo saltamos.
# ❌ Chunk 45 tiene NaNs, lo saltamos.
# ❌ Chunk 46 tiene NaNs, lo saltamos.
# ❌ Chunk 47 tiene NaNs, lo saltamos.
# ❌ Chunk 48 tiene NaNs, lo saltamos.
# ❌ Chunk 49 tiene NaNs, lo saltamos.
# ❌ Chunk 50 tiene NaNs, lo saltamos.
# ❌ Chunk 51 tiene NaNs, lo saltamos.
# ❌ Chunk 52 tiene NaNs, lo saltamos.
# ❌ Chunk 53 tiene NaNs, lo saltamos.
# ❌ Chunk 54 tiene NaNs, lo saltamos.
# ❌ Chunk 55 tiene NaNs, lo saltamos.
#
# 🌀 Época 2/10
# ❌ Chunk 0 tiene NaNs, lo saltamos.
# ❌ Chunk 1 tiene NaNs, lo saltamos.
# ❌ Chunk 2 tiene NaNs, lo saltamos.
# ❌ Chunk 3 tiene NaNs, lo saltamos.
# ❌ Chunk 4 tiene NaNs, lo saltamos.
# ❌ Chunk 5 tiene NaNs, lo saltamos.
# ❌ Chunk 6 tiene NaNs, lo saltamos.
# ❌ Chunk 7 tiene NaNs, lo saltamos.
# ❌ Chunk 8 tiene NaNs, lo saltamos.
# ❌ Chunk 9 tiene NaNs, lo saltamos.
# ❌ Chunk 10 tiene NaNs, lo saltamos.
# ❌ Chunk 11 tiene NaNs, lo saltamos.
# ❌ Chunk 12 tiene NaNs, lo saltamos.
# ❌ Chunk 13 tiene NaNs, lo saltamos.
# ❌ Chunk 14 tiene NaNs, lo saltamos.
# ❌ Chunk 15 tiene NaNs, lo saltamos.
# ❌ Chunk 16 tiene NaNs, lo saltamos.
# ❌ Chunk 17 tiene NaNs, lo saltamos.
# ❌ Chunk 18 tiene NaNs, lo saltamos.
# ❌ Chunk 19 tiene NaNs, lo saltamos.
# ❌ Chunk 20 tiene NaNs, lo saltamos.
# ❌ Chunk 21 tiene NaNs, lo saltamos.
# ❌ Chunk 22 tiene NaNs, lo saltamos.
# ❌ Chunk 23 tiene NaNs, lo saltamos.
# ❌ Chunk 24 tiene NaNs, lo saltamos.
# ❌ Chunk 25 tiene NaNs, lo saltamos.
# ❌ Chunk 26 tiene NaNs, lo saltamos.
# ❌ Chunk 27 tiene NaNs, lo saltamos.
# ❌ Chunk 28 tiene NaNs, lo saltamos.
# ❌ Chunk 29 tiene NaNs, lo saltamos.
# ❌ Chunk 30 tiene NaNs, lo saltamos.
# ❌ Chunk 31 tiene NaNs, lo saltamos.
# ❌ Chunk 32 tiene NaNs, lo saltamos.
# ❌ Chunk 33 tiene NaNs, lo saltamos.
# ❌ Chunk 34 tiene NaNs, lo saltamos.
# ❌ Chunk 35 tiene NaNs, lo saltamos.
# ❌ Chunk 36 tiene NaNs, lo saltamos.
# ❌ Chunk 37 tiene NaNs, lo saltamos.
# ❌ Chunk 38 tiene NaNs, lo saltamos.
# ❌ Chunk 39 tiene NaNs, lo saltamos.
# ❌ Chunk 40 tiene NaNs, lo saltamos.
# ❌ Chunk 41 tiene NaNs, lo saltamos.
# ❌ Chunk 42 tiene NaNs, lo saltamos.
# ❌ Chunk 43 tiene NaNs, lo saltamos.
# ❌ Chunk 44 tiene NaNs, lo saltamos.
# ❌ Chunk 45 tiene NaNs, lo saltamos.
# ❌ Chunk 46 tiene NaNs, lo saltamos.
# ❌ Chunk 47 tiene NaNs, lo saltamos.
# ❌ Chunk 48 tiene NaNs, lo saltamos.
# ❌ Chunk 49 tiene NaNs, lo saltamos.
# ❌ Chunk 50 tiene NaNs, lo saltamos.
# ❌ Chunk 51 tiene NaNs, lo saltamos.
# ❌ Chunk 52 tiene NaNs, lo saltamos.
# ❌ Chunk 53 tiene NaNs, lo saltamos.
# ❌ Chunk 54 tiene NaNs, lo saltamos.
# ❌ Chunk 55 tiene NaNs, lo saltamos.
#
# 🌀 Época 3/10
# ❌ Chunk 0 tiene NaNs, lo saltamos.
# ❌ Chunk 1 tiene NaNs, lo saltamos.
# ❌ Chunk 2 tiene NaNs, lo saltamos.
# ❌ Chunk 3 tiene NaNs, lo saltamos.
# ❌ Chunk 4 tiene NaNs, lo saltamos.
# ❌ Chunk 5 tiene NaNs, lo saltamos.
# ❌ Chunk 6 tiene NaNs, lo saltamos.
# ❌ Chunk 7 tiene NaNs, lo saltamos.
# ❌ Chunk 8 tiene NaNs, lo saltamos.
# ❌ Chunk 9 tiene NaNs, lo saltamos.
# ❌ Chunk 10 tiene NaNs, lo saltamos.
# ❌ Chunk 11 tiene NaNs, lo saltamos.
# ❌ Chunk 12 tiene NaNs, lo saltamos.
# ❌ Chunk 13 tiene NaNs, lo saltamos.
# ❌ Chunk 14 tiene NaNs, lo saltamos.
# ❌ Chunk 15 tiene NaNs, lo saltamos.
# ❌ Chunk 16 tiene NaNs, lo saltamos.
# ❌ Chunk 17 tiene NaNs, lo saltamos.
# ❌ Chunk 18 tiene NaNs, lo saltamos.
# ❌ Chunk 19 tiene NaNs, lo saltamos.
# ❌ Chunk 20 tiene NaNs, lo saltamos.
# ❌ Chunk 21 tiene NaNs, lo saltamos.
# ❌ Chunk 22 tiene NaNs, lo saltamos.
# ❌ Chunk 23 tiene NaNs, lo saltamos.
# ❌ Chunk 24 tiene NaNs, lo saltamos.
# ❌ Chunk 25 tiene NaNs, lo saltamos.
# ❌ Chunk 26 tiene NaNs, lo saltamos.
# ❌ Chunk 27 tiene NaNs, lo saltamos.
# ❌ Chunk 28 tiene NaNs, lo saltamos.
# ❌ Chunk 29 tiene NaNs, lo saltamos.
# ❌ Chunk 30 tiene NaNs, lo saltamos.
# ❌ Chunk 31 tiene NaNs, lo saltamos.
# ❌ Chunk 32 tiene NaNs, lo saltamos.
# ❌ Chunk 33 tiene NaNs, lo saltamos.
# ❌ Chunk 34 tiene NaNs, lo saltamos.
# ❌ Chunk 35 tiene NaNs, lo saltamos.
# ❌ Chunk 36 tiene NaNs, lo saltamos.
# ❌ Chunk 37 tiene NaNs, lo saltamos.
# ❌ Chunk 38 tiene NaNs, lo saltamos.
# ❌ Chunk 39 tiene NaNs, lo saltamos.
# ❌ Chunk 40 tiene NaNs, lo saltamos.
# ❌ Chunk 41 tiene NaNs, lo saltamos.
# ❌ Chunk 42 tiene NaNs, lo saltamos.
# ❌ Chunk 43 tiene NaNs, lo saltamos.
# ❌ Chunk 44 tiene NaNs, lo saltamos.
# ❌ Chunk 45 tiene NaNs, lo saltamos.
# ❌ Chunk 46 tiene NaNs, lo saltamos.
# ❌ Chunk 47 tiene NaNs, lo saltamos.
# ❌ Chunk 48 tiene NaNs, lo saltamos.
# ❌ Chunk 49 tiene NaNs, lo saltamos.
# ❌ Chunk 50 tiene NaNs, lo saltamos.
# ❌ Chunk 51 tiene NaNs, lo saltamos.
# ❌ Chunk 52 tiene NaNs, lo saltamos.
# ❌ Chunk 53 tiene NaNs, lo saltamos.
# ❌ Chunk 54 tiene NaNs, lo saltamos.
# ❌ Chunk 55 tiene NaNs, lo saltamos.
#
# 🌀 Época 4/10
# ❌ Chunk 0 tiene NaNs, lo saltamos.
# ❌ Chunk 1 tiene NaNs, lo saltamos.
# ❌ Chunk 2 tiene NaNs, lo saltamos.
# ❌ Chunk 3 tiene NaNs, lo saltamos.
# ❌ Chunk 4 tiene NaNs, lo saltamos.
# ❌ Chunk 5 tiene NaNs, lo saltamos.
# ❌ Chunk 6 tiene NaNs, lo saltamos.
# ❌ Chunk 7 tiene NaNs, lo saltamos.
# ❌ Chunk 8 tiene NaNs, lo saltamos.
# ❌ Chunk 9 tiene NaNs, lo saltamos.
# ❌ Chunk 10 tiene NaNs, lo saltamos.
# ❌ Chunk 11 tiene NaNs, lo saltamos.
# ❌ Chunk 12 tiene NaNs, lo saltamos.
# ❌ Chunk 13 tiene NaNs, lo saltamos.
# ❌ Chunk 14 tiene NaNs, lo saltamos.
# ❌ Chunk 15 tiene NaNs, lo saltamos.
# ❌ Chunk 16 tiene NaNs, lo saltamos.
# ❌ Chunk 17 tiene NaNs, lo saltamos.
# ❌ Chunk 18 tiene NaNs, lo saltamos.
# ❌ Chunk 19 tiene NaNs, lo saltamos.
# ❌ Chunk 20 tiene NaNs, lo saltamos.
# ❌ Chunk 21 tiene NaNs, lo saltamos.
# ❌ Chunk 22 tiene NaNs, lo saltamos.
# ❌ Chunk 23 tiene NaNs, lo saltamos.
# ❌ Chunk 24 tiene NaNs, lo saltamos.
# ❌ Chunk 25 tiene NaNs, lo saltamos.
# ❌ Chunk 26 tiene NaNs, lo saltamos.
# ❌ Chunk 27 tiene NaNs, lo saltamos.
# ❌ Chunk 28 tiene NaNs, lo saltamos.
# ❌ Chunk 29 tiene NaNs, lo saltamos.
# ❌ Chunk 30 tiene NaNs, lo saltamos.
# ❌ Chunk 31 tiene NaNs, lo saltamos.
# ❌ Chunk 32 tiene NaNs, lo saltamos.
# ❌ Chunk 33 tiene NaNs, lo saltamos.
# ❌ Chunk 34 tiene NaNs, lo saltamos.
# ❌ Chunk 35 tiene NaNs, lo saltamos.
# ❌ Chunk 36 tiene NaNs, lo saltamos.
# ❌ Chunk 37 tiene NaNs, lo saltamos.
# ❌ Chunk 38 tiene NaNs, lo saltamos.
# ❌ Chunk 39 tiene NaNs, lo saltamos.
# ❌ Chunk 40 tiene NaNs, lo saltamos.
# ❌ Chunk 41 tiene NaNs, lo saltamos.
# ❌ Chunk 42 tiene NaNs, lo saltamos.
# ❌ Chunk 43 tiene NaNs, lo saltamos.
# ❌ Chunk 44 tiene NaNs, lo saltamos.
# ❌ Chunk 45 tiene NaNs, lo saltamos.
# ❌ Chunk 46 tiene NaNs, lo saltamos.
# ❌ Chunk 47 tiene NaNs, lo saltamos.
# ❌ Chunk 48 tiene NaNs, lo saltamos.
# ❌ Chunk 49 tiene NaNs, lo saltamos.
# ❌ Chunk 50 tiene NaNs, lo saltamos.
# ❌ Chunk 51 tiene NaNs, lo saltamos.
# ❌ Chunk 52 tiene NaNs, lo saltamos.
# ❌ Chunk 53 tiene NaNs, lo saltamos.
# ❌ Chunk 54 tiene NaNs, lo saltamos.
# ❌ Chunk 55 tiene NaNs, lo saltamos.
#
# 🌀 Época 5/10
# ❌ Chunk 0 tiene NaNs, lo saltamos.
# ❌ Chunk 1 tiene NaNs, lo saltamos.
# ❌ Chunk 2 tiene NaNs, lo saltamos.
# ❌ Chunk 3 tiene NaNs, lo saltamos.
# ❌ Chunk 4 tiene NaNs, lo saltamos.
# ❌ Chunk 5 tiene NaNs, lo saltamos.
# ❌ Chunk 6 tiene NaNs, lo saltamos.
# ❌ Chunk 7 tiene NaNs, lo saltamos.
# ❌ Chunk 8 tiene NaNs, lo saltamos.
# ❌ Chunk 9 tiene NaNs, lo saltamos.
# ❌ Chunk 10 tiene NaNs, lo saltamos.
# ❌ Chunk 11 tiene NaNs, lo saltamos.
# ❌ Chunk 12 tiene NaNs, lo saltamos.
# ❌ Chunk 13 tiene NaNs, lo saltamos.
# ❌ Chunk 14 tiene NaNs, lo saltamos.
# ❌ Chunk 15 tiene NaNs, lo saltamos.
# ❌ Chunk 16 tiene NaNs, lo saltamos.
# ❌ Chunk 17 tiene NaNs, lo saltamos.
# ❌ Chunk 18 tiene NaNs, lo saltamos.
# ❌ Chunk 19 tiene NaNs, lo saltamos.
# ❌ Chunk 20 tiene NaNs, lo saltamos.
# ❌ Chunk 21 tiene NaNs, lo saltamos.
# ❌ Chunk 22 tiene NaNs, lo saltamos.
# ❌ Chunk 23 tiene NaNs, lo saltamos.
# ❌ Chunk 24 tiene NaNs, lo saltamos.
# ❌ Chunk 25 tiene NaNs, lo saltamos.
# ❌ Chunk 26 tiene NaNs, lo saltamos.
# ❌ Chunk 27 tiene NaNs, lo saltamos.
# ❌ Chunk 28 tiene NaNs, lo saltamos.
# ❌ Chunk 29 tiene NaNs, lo saltamos.
# ❌ Chunk 30 tiene NaNs, lo saltamos.
# ❌ Chunk 31 tiene NaNs, lo saltamos.
# ❌ Chunk 32 tiene NaNs, lo saltamos.
# ❌ Chunk 33 tiene NaNs, lo saltamos.
# ❌ Chunk 34 tiene NaNs, lo saltamos.
# ❌ Chunk 35 tiene NaNs, lo saltamos.
# ❌ Chunk 36 tiene NaNs, lo saltamos.
# ❌ Chunk 37 tiene NaNs, lo saltamos.
# ❌ Chunk 38 tiene NaNs, lo saltamos.
# ❌ Chunk 39 tiene NaNs, lo saltamos.
# ❌ Chunk 40 tiene NaNs, lo saltamos.
# ❌ Chunk 41 tiene NaNs, lo saltamos.
# ❌ Chunk 42 tiene NaNs, lo saltamos.
# ❌ Chunk 43 tiene NaNs, lo saltamos.
# ❌ Chunk 44 tiene NaNs, lo saltamos.
# ❌ Chunk 45 tiene NaNs, lo saltamos.
# ❌ Chunk 46 tiene NaNs, lo saltamos.
# ❌ Chunk 47 tiene NaNs, lo saltamos.
# ❌ Chunk 48 tiene NaNs, lo saltamos.
# ❌ Chunk 49 tiene NaNs, lo saltamos.
# ❌ Chunk 50 tiene NaNs, lo saltamos.
# ❌ Chunk 51 tiene NaNs, lo saltamos.
# ❌ Chunk 52 tiene NaNs, lo saltamos.
# ❌ Chunk 53 tiene NaNs, lo saltamos.
# ❌ Chunk 54 tiene NaNs, lo saltamos.
# ❌ Chunk 55 tiene NaNs, lo saltamos.
#
# 🌀 Época 6/10
# ❌ Chunk 0 tiene NaNs, lo saltamos.
# ❌ Chunk 1 tiene NaNs, lo saltamos.
# ❌ Chunk 2 tiene NaNs, lo saltamos.
# ❌ Chunk 3 tiene NaNs, lo saltamos.
# ❌ Chunk 4 tiene NaNs, lo saltamos.
# ❌ Chunk 5 tiene NaNs, lo saltamos.
# ❌ Chunk 6 tiene NaNs, lo saltamos.
# ❌ Chunk 7 tiene NaNs, lo saltamos.
# ❌ Chunk 8 tiene NaNs, lo saltamos.
# ❌ Chunk 9 tiene NaNs, lo saltamos.
# ❌ Chunk 10 tiene NaNs, lo saltamos.
# ❌ Chunk 11 tiene NaNs, lo saltamos.
# ❌ Chunk 12 tiene NaNs, lo saltamos.
# ❌ Chunk 13 tiene NaNs, lo saltamos.
# ❌ Chunk 14 tiene NaNs, lo saltamos.
# ❌ Chunk 15 tiene NaNs, lo saltamos.
# ❌ Chunk 16 tiene NaNs, lo saltamos.
# ❌ Chunk 17 tiene NaNs, lo saltamos.
# ❌ Chunk 18 tiene NaNs, lo saltamos.
# ❌ Chunk 19 tiene NaNs, lo saltamos.
# ❌ Chunk 20 tiene NaNs, lo saltamos.
# ❌ Chunk 21 tiene NaNs, lo saltamos.
# ❌ Chunk 22 tiene NaNs, lo saltamos.
# ❌ Chunk 23 tiene NaNs, lo saltamos.
# ❌ Chunk 24 tiene NaNs, lo saltamos.
# ❌ Chunk 25 tiene NaNs, lo saltamos.
# ❌ Chunk 26 tiene NaNs, lo saltamos.
# ❌ Chunk 27 tiene NaNs, lo saltamos.
# ❌ Chunk 28 tiene NaNs, lo saltamos.
# ❌ Chunk 29 tiene NaNs, lo saltamos.
# ❌ Chunk 30 tiene NaNs, lo saltamos.
# ❌ Chunk 31 tiene NaNs, lo saltamos.
# ❌ Chunk 32 tiene NaNs, lo saltamos.
# ❌ Chunk 33 tiene NaNs, lo saltamos.
# ❌ Chunk 34 tiene NaNs, lo saltamos.
# ❌ Chunk 35 tiene NaNs, lo saltamos.
# ❌ Chunk 36 tiene NaNs, lo saltamos.
# ❌ Chunk 37 tiene NaNs, lo saltamos.
# ❌ Chunk 38 tiene NaNs, lo saltamos.
# ❌ Chunk 39 tiene NaNs, lo saltamos.
# ❌ Chunk 40 tiene NaNs, lo saltamos.
# ❌ Chunk 41 tiene NaNs, lo saltamos.
# ❌ Chunk 42 tiene NaNs, lo saltamos.
# ❌ Chunk 43 tiene NaNs, lo saltamos.
# ❌ Chunk 44 tiene NaNs, lo saltamos.
# ❌ Chunk 45 tiene NaNs, lo saltamos.
# ❌ Chunk 46 tiene NaNs, lo saltamos.
# ❌ Chunk 47 tiene NaNs, lo saltamos.
# ❌ Chunk 48 tiene NaNs, lo saltamos.
# ❌ Chunk 49 tiene NaNs, lo saltamos.
# ❌ Chunk 50 tiene NaNs, lo saltamos.
# ❌ Chunk 51 tiene NaNs, lo saltamos.
# ❌ Chunk 52 tiene NaNs, lo saltamos.
# ❌ Chunk 53 tiene NaNs, lo saltamos.
# ❌ Chunk 54 tiene NaNs, lo saltamos.
# ❌ Chunk 55 tiene NaNs, lo saltamos.
#
# 🌀 Época 7/10
# ❌ Chunk 0 tiene NaNs, lo saltamos.
# ❌ Chunk 1 tiene NaNs, lo saltamos.
# ❌ Chunk 2 tiene NaNs, lo saltamos.
# ❌ Chunk 3 tiene NaNs, lo saltamos.
# ❌ Chunk 4 tiene NaNs, lo saltamos.
# ❌ Chunk 5 tiene NaNs, lo saltamos.
# ❌ Chunk 6 tiene NaNs, lo saltamos.
# ❌ Chunk 7 tiene NaNs, lo saltamos.
# ❌ Chunk 8 tiene NaNs, lo saltamos.
# ❌ Chunk 9 tiene NaNs, lo saltamos.
# ❌ Chunk 10 tiene NaNs, lo saltamos.
# ❌ Chunk 11 tiene NaNs, lo saltamos.
# ❌ Chunk 12 tiene NaNs, lo saltamos.
# ❌ Chunk 13 tiene NaNs, lo saltamos.
# ❌ Chunk 14 tiene NaNs, lo saltamos.
# ❌ Chunk 15 tiene NaNs, lo saltamos.
# ❌ Chunk 16 tiene NaNs, lo saltamos.
# ❌ Chunk 17 tiene NaNs, lo saltamos.
# ❌ Chunk 18 tiene NaNs, lo saltamos.
# ❌ Chunk 19 tiene NaNs, lo saltamos.
# ❌ Chunk 20 tiene NaNs, lo saltamos.
# ❌ Chunk 21 tiene NaNs, lo saltamos.
# ❌ Chunk 22 tiene NaNs, lo saltamos.
# ❌ Chunk 23 tiene NaNs, lo saltamos.
# ❌ Chunk 24 tiene NaNs, lo saltamos.
# ❌ Chunk 25 tiene NaNs, lo saltamos.
# ❌ Chunk 26 tiene NaNs, lo saltamos.
# ❌ Chunk 27 tiene NaNs, lo saltamos.
# ❌ Chunk 28 tiene NaNs, lo saltamos.
# ❌ Chunk 29 tiene NaNs, lo saltamos.
# ❌ Chunk 30 tiene NaNs, lo saltamos.
# ❌ Chunk 31 tiene NaNs, lo saltamos.
# ❌ Chunk 32 tiene NaNs, lo saltamos.
# ❌ Chunk 33 tiene NaNs, lo saltamos.
# ❌ Chunk 34 tiene NaNs, lo saltamos.
# ❌ Chunk 35 tiene NaNs, lo saltamos.
# ❌ Chunk 36 tiene NaNs, lo saltamos.
# ❌ Chunk 37 tiene NaNs, lo saltamos.
# ❌ Chunk 38 tiene NaNs, lo saltamos.
# ❌ Chunk 39 tiene NaNs, lo saltamos.
# ❌ Chunk 40 tiene NaNs, lo saltamos.
# ❌ Chunk 41 tiene NaNs, lo saltamos.
# ❌ Chunk 42 tiene NaNs, lo saltamos.
# ❌ Chunk 43 tiene NaNs, lo saltamos.
# ❌ Chunk 44 tiene NaNs, lo saltamos.
# ❌ Chunk 45 tiene NaNs, lo saltamos.
# ❌ Chunk 46 tiene NaNs, lo saltamos.
# ❌ Chunk 47 tiene NaNs, lo saltamos.
# ❌ Chunk 48 tiene NaNs, lo saltamos.
# ❌ Chunk 49 tiene NaNs, lo saltamos.
# ❌ Chunk 50 tiene NaNs, lo saltamos.
# ❌ Chunk 51 tiene NaNs, lo saltamos.
# ❌ Chunk 52 tiene NaNs, lo saltamos.
# ❌ Chunk 53 tiene NaNs, lo saltamos.
# ❌ Chunk 54 tiene NaNs, lo saltamos.
# ❌ Chunk 55 tiene NaNs, lo saltamos.
#
# 🌀 Época 8/10
# ❌ Chunk 0 tiene NaNs, lo saltamos.
# ❌ Chunk 1 tiene NaNs, lo saltamos.
# ❌ Chunk 2 tiene NaNs, lo saltamos.
# ❌ Chunk 3 tiene NaNs, lo saltamos.
# ❌ Chunk 4 tiene NaNs, lo saltamos.
# ❌ Chunk 5 tiene NaNs, lo saltamos.
# ❌ Chunk 6 tiene NaNs, lo saltamos.
# ❌ Chunk 7 tiene NaNs, lo saltamos.
# ❌ Chunk 8 tiene NaNs, lo saltamos.
# ❌ Chunk 9 tiene NaNs, lo saltamos.
# ❌ Chunk 10 tiene NaNs, lo saltamos.
# ❌ Chunk 11 tiene NaNs, lo saltamos.
# ❌ Chunk 12 tiene NaNs, lo saltamos.
# ❌ Chunk 13 tiene NaNs, lo saltamos.
# ❌ Chunk 14 tiene NaNs, lo saltamos.
# ❌ Chunk 15 tiene NaNs, lo saltamos.
# ❌ Chunk 16 tiene NaNs, lo saltamos.
# ❌ Chunk 17 tiene NaNs, lo saltamos.
# ❌ Chunk 18 tiene NaNs, lo saltamos.
# ❌ Chunk 19 tiene NaNs, lo saltamos.
# ❌ Chunk 20 tiene NaNs, lo saltamos.
# ❌ Chunk 21 tiene NaNs, lo saltamos.
# ❌ Chunk 22 tiene NaNs, lo saltamos.
# ❌ Chunk 23 tiene NaNs, lo saltamos.
# ❌ Chunk 24 tiene NaNs, lo saltamos.
# ❌ Chunk 25 tiene NaNs, lo saltamos.
# ❌ Chunk 26 tiene NaNs, lo saltamos.
# ❌ Chunk 27 tiene NaNs, lo saltamos.
# ❌ Chunk 28 tiene NaNs, lo saltamos.
# ❌ Chunk 29 tiene NaNs, lo saltamos.
# ❌ Chunk 30 tiene NaNs, lo saltamos.
# ❌ Chunk 31 tiene NaNs, lo saltamos.
# ❌ Chunk 32 tiene NaNs, lo saltamos.
# ❌ Chunk 33 tiene NaNs, lo saltamos.
# ❌ Chunk 34 tiene NaNs, lo saltamos.
# ❌ Chunk 35 tiene NaNs, lo saltamos.
# ❌ Chunk 36 tiene NaNs, lo saltamos.
# ❌ Chunk 37 tiene NaNs, lo saltamos.
# ❌ Chunk 38 tiene NaNs, lo saltamos.
# ❌ Chunk 39 tiene NaNs, lo saltamos.
# ❌ Chunk 40 tiene NaNs, lo saltamos.
# ❌ Chunk 41 tiene NaNs, lo saltamos.
# ❌ Chunk 42 tiene NaNs, lo saltamos.
# ❌ Chunk 43 tiene NaNs, lo saltamos.
# ❌ Chunk 44 tiene NaNs, lo saltamos.
# ❌ Chunk 45 tiene NaNs, lo saltamos.
# ❌ Chunk 46 tiene NaNs, lo saltamos.
# ❌ Chunk 47 tiene NaNs, lo saltamos.
# ❌ Chunk 48 tiene NaNs, lo saltamos.
# ❌ Chunk 49 tiene NaNs, lo saltamos.
# ❌ Chunk 50 tiene NaNs, lo saltamos.
# ❌ Chunk 51 tiene NaNs, lo saltamos.
# ❌ Chunk 52 tiene NaNs, lo saltamos.
# ❌ Chunk 53 tiene NaNs, lo saltamos.
# ❌ Chunk 54 tiene NaNs, lo saltamos.
# ❌ Chunk 55 tiene NaNs, lo saltamos.
#
# 🌀 Época 9/10
# ❌ Chunk 0 tiene NaNs, lo saltamos.
# ❌ Chunk 1 tiene NaNs, lo saltamos.
# ❌ Chunk 2 tiene NaNs, lo saltamos.
# ❌ Chunk 3 tiene NaNs, lo saltamos.
# ❌ Chunk 4 tiene NaNs, lo saltamos.
# ❌ Chunk 5 tiene NaNs, lo saltamos.
# ❌ Chunk 6 tiene NaNs, lo saltamos.
# ❌ Chunk 7 tiene NaNs, lo saltamos.
# ❌ Chunk 8 tiene NaNs, lo saltamos.
# ❌ Chunk 9 tiene NaNs, lo saltamos.
# ❌ Chunk 10 tiene NaNs, lo saltamos.
# ❌ Chunk 11 tiene NaNs, lo saltamos.
# ❌ Chunk 12 tiene NaNs, lo saltamos.
# ❌ Chunk 13 tiene NaNs, lo saltamos.
# ❌ Chunk 14 tiene NaNs, lo saltamos.
# ❌ Chunk 15 tiene NaNs, lo saltamos.
# ❌ Chunk 16 tiene NaNs, lo saltamos.
# ❌ Chunk 17 tiene NaNs, lo saltamos.
# ❌ Chunk 18 tiene NaNs, lo saltamos.
# ❌ Chunk 19 tiene NaNs, lo saltamos.
# ❌ Chunk 20 tiene NaNs, lo saltamos.
# ❌ Chunk 21 tiene NaNs, lo saltamos.
# ❌ Chunk 22 tiene NaNs, lo saltamos.
# ❌ Chunk 23 tiene NaNs, lo saltamos.
# ❌ Chunk 24 tiene NaNs, lo saltamos.
# ❌ Chunk 25 tiene NaNs, lo saltamos.
# ❌ Chunk 26 tiene NaNs, lo saltamos.
# ❌ Chunk 27 tiene NaNs, lo saltamos.
# ❌ Chunk 28 tiene NaNs, lo saltamos.
# ❌ Chunk 29 tiene NaNs, lo saltamos.
# ❌ Chunk 30 tiene NaNs, lo saltamos.
# ❌ Chunk 31 tiene NaNs, lo saltamos.
# ❌ Chunk 32 tiene NaNs, lo saltamos.
# ❌ Chunk 33 tiene NaNs, lo saltamos.
# ❌ Chunk 34 tiene NaNs, lo saltamos.
# ❌ Chunk 35 tiene NaNs, lo saltamos.
# ❌ Chunk 36 tiene NaNs, lo saltamos.
# ❌ Chunk 37 tiene NaNs, lo saltamos.
# ❌ Chunk 38 tiene NaNs, lo saltamos.
# ❌ Chunk 39 tiene NaNs, lo saltamos.
# ❌ Chunk 40 tiene NaNs, lo saltamos.
# ❌ Chunk 41 tiene NaNs, lo saltamos.
# ❌ Chunk 42 tiene NaNs, lo saltamos.
# ❌ Chunk 43 tiene NaNs, lo saltamos.
# ❌ Chunk 44 tiene NaNs, lo saltamos.
# ❌ Chunk 45 tiene NaNs, lo saltamos.
# ❌ Chunk 46 tiene NaNs, lo saltamos.
# ❌ Chunk 47 tiene NaNs, lo saltamos.
# ❌ Chunk 48 tiene NaNs, lo saltamos.
# ❌ Chunk 49 tiene NaNs, lo saltamos.
# ❌ Chunk 50 tiene NaNs, lo saltamos.
# ❌ Chunk 51 tiene NaNs, lo saltamos.
# ❌ Chunk 52 tiene NaNs, lo saltamos.
# ❌ Chunk 53 tiene NaNs, lo saltamos.
# ❌ Chunk 54 tiene NaNs, lo saltamos.
# ❌ Chunk 55 tiene NaNs, lo saltamos.
#
# 🌀 Época 10/10
# ❌ Chunk 0 tiene NaNs, lo saltamos.
# ❌ Chunk 1 tiene NaNs, lo saltamos.
# ❌ Chunk 2 tiene NaNs, lo saltamos.
# ❌ Chunk 3 tiene NaNs, lo saltamos.
# ❌ Chunk 4 tiene NaNs, lo saltamos.
# ❌ Chunk 5 tiene NaNs, lo saltamos.
# ❌ Chunk 6 tiene NaNs, lo saltamos.
# ❌ Chunk 7 tiene NaNs, lo saltamos.
# ❌ Chunk 8 tiene NaNs, lo saltamos.
# ❌ Chunk 9 tiene NaNs, lo saltamos.
# ❌ Chunk 10 tiene NaNs, lo saltamos.
# ❌ Chunk 11 tiene NaNs, lo saltamos.
# ❌ Chunk 12 tiene NaNs, lo saltamos.
# ❌ Chunk 13 tiene NaNs, lo saltamos.
# ❌ Chunk 14 tiene NaNs, lo saltamos.
# ❌ Chunk 15 tiene NaNs, lo saltamos.
# ❌ Chunk 16 tiene NaNs, lo saltamos.
# ❌ Chunk 17 tiene NaNs, lo saltamos.
# ❌ Chunk 18 tiene NaNs, lo saltamos.
# ❌ Chunk 19 tiene NaNs, lo saltamos.
# ❌ Chunk 20 tiene NaNs, lo saltamos.
# ❌ Chunk 21 tiene NaNs, lo saltamos.
# ❌ Chunk 22 tiene NaNs, lo saltamos.
# ❌ Chunk 23 tiene NaNs, lo saltamos.
# ❌ Chunk 24 tiene NaNs, lo saltamos.
# ❌ Chunk 25 tiene NaNs, lo saltamos.
# ❌ Chunk 26 tiene NaNs, lo saltamos.
# ❌ Chunk 27 tiene NaNs, lo saltamos.
# ❌ Chunk 28 tiene NaNs, lo saltamos.
# ❌ Chunk 29 tiene NaNs, lo saltamos.
# ❌ Chunk 30 tiene NaNs, lo saltamos.
# ❌ Chunk 31 tiene NaNs, lo saltamos.
# ❌ Chunk 32 tiene NaNs, lo saltamos.
# ❌ Chunk 33 tiene NaNs, lo saltamos.
# ❌ Chunk 34 tiene NaNs, lo saltamos.
# ❌ Chunk 35 tiene NaNs, lo saltamos.
# ❌ Chunk 36 tiene NaNs, lo saltamos.
# ❌ Chunk 37 tiene NaNs, lo saltamos.
# ❌ Chunk 38 tiene NaNs, lo saltamos.
# ❌ Chunk 39 tiene NaNs, lo saltamos.
# ❌ Chunk 40 tiene NaNs, lo saltamos.
# ❌ Chunk 41 tiene NaNs, lo saltamos.
# ❌ Chunk 42 tiene NaNs, lo saltamos.
# ❌ Chunk 43 tiene NaNs, lo saltamos.
# ❌ Chunk 44 tiene NaNs, lo saltamos.
# ❌ Chunk 45 tiene NaNs, lo saltamos.
# ❌ Chunk 46 tiene NaNs, lo saltamos.
# ❌ Chunk 47 tiene NaNs, lo saltamos.
# ❌ Chunk 48 tiene NaNs, lo saltamos.
# ❌ Chunk 49 tiene NaNs, lo saltamos.
# ❌ Chunk 50 tiene NaNs, lo saltamos.
# ❌ Chunk 51 tiene NaNs, lo saltamos.
# ❌ Chunk 52 tiene NaNs, lo saltamos.
# ❌ Chunk 53 tiene NaNs, lo saltamos.
# ❌ Chunk 54 tiene NaNs, lo saltamos.
# ❌ Chunk 55 tiene NaNs, lo saltamos.
#
# 📊 Evaluando el modelo sobre todos los test chunks...
# ❌ Chunk 0 tiene NaNs, lo saltamos.
# ❌ Chunk 1 tiene NaNs, lo saltamos.
# ❌ Chunk 2 tiene NaNs, lo saltamos.
# ❌ Chunk 3 tiene NaNs, lo saltamos.
# ❌ Chunk 4 tiene NaNs, lo saltamos.
# ❌ Chunk 5 tiene NaNs, lo saltamos.
# ❌ Chunk 6 tiene NaNs, lo saltamos.
# ❌ Chunk 7 tiene NaNs, lo saltamos.
# ❌ Chunk 8 tiene NaNs, lo saltamos.
# ❌ Chunk 9 tiene NaNs, lo saltamos.
# ❌ Chunk 10 tiene NaNs, lo saltamos.
# ❌ Chunk 11 tiene NaNs, lo saltamos.
# ❌ Chunk 12 tiene NaNs, lo saltamos.
# ❌ Chunk 13 tiene NaNs, lo saltamos.
# ❌ Chunk 14 tiene NaNs, lo saltamos.
# ❌ Chunk 15 tiene NaNs, lo saltamos.
# ❌ Chunk 16 tiene NaNs, lo saltamos.
# ❌ Chunk 17 tiene NaNs, lo saltamos.
# ❌ Chunk 18 tiene NaNs, lo saltamos.
# ❌ Chunk 19 tiene NaNs, lo saltamos.
# ❌ Chunk 20 tiene NaNs, lo saltamos.
# ❌ Chunk 21 tiene NaNs, lo saltamos.
# ❌ Chunk 22 tiene NaNs, lo saltamos.
# ❌ Chunk 23 tiene NaNs, lo saltamos.
# ❌ Chunk 24 tiene NaNs, lo saltamos.
# ❌ Chunk 25 tiene NaNs, lo saltamos.
# ❌ Chunk 26 tiene NaNs, lo saltamos.
# ❌ Chunk 27 tiene NaNs, lo saltamos.
# ❌ Chunk 28 tiene NaNs, lo saltamos.
# ❌ Chunk 29 tiene NaNs, lo saltamos.
# ❌ Chunk 30 tiene NaNs, lo saltamos.
# ❌ Chunk 31 tiene NaNs, lo saltamos.
# ❌ Chunk 32 tiene NaNs, lo saltamos.
# ❌ Chunk 33 tiene NaNs, lo saltamos.
# ❌ Chunk 34 tiene NaNs, lo saltamos.
# ❌ Chunk 35 tiene NaNs, lo saltamos.
# ❌ Chunk 36 tiene NaNs, lo saltamos.
# ❌ Chunk 37 tiene NaNs, lo saltamos.
# ❌ Chunk 38 tiene NaNs, lo saltamos.
# ❌ Chunk 39 tiene NaNs, lo saltamos.
# ❌ Chunk 40 tiene NaNs, lo saltamos.
# ❌ Chunk 41 tiene NaNs, lo saltamos.
# ❌ Chunk 42 tiene NaNs, lo saltamos.
# ❌ Chunk 43 tiene NaNs, lo saltamos.
# ❌ Chunk 44 tiene NaNs, lo saltamos.
# ❌ Chunk 45 tiene NaNs, lo saltamos.
# ❌ Chunk 46 tiene NaNs, lo saltamos.
# ❌ Chunk 47 tiene NaNs, lo saltamos.
# ❌ Chunk 48 tiene NaNs, lo saltamos.
# ❌ Chunk 49 tiene NaNs, lo saltamos.
# ❌ Chunk 50 tiene NaNs, lo saltamos.
# ❌ Chunk 51 tiene NaNs, lo saltamos.
# ❌ Chunk 52 tiene NaNs, lo saltamos.
# ❌ Chunk 53 tiene NaNs, lo saltamos.
# ❌ Chunk 54 tiene NaNs, lo saltamos.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ❌ Chunk 55 tiene NaNs, lo saltamos.
# ⚠️ No se pudo evaluar el modelo: ningún chunk válido.
#
# 💾 Modelo guardado en: ../models/flight_price_predictor_v3_clean_scaled.h5

# %%
print("Shape de X_train:", X_train.shape)
print("Shape de y_train:", y_train.shape)
# Out:
# Shape de X_train: (838860, 21)
# Shape de y_train: (838860,)

# %%
import os
print(os.getcwd())
# Out:
# /home/cosmopato/FlightPriceProject/notebooks
